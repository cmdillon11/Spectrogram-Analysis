# %%
import numpy as np
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.pyplot as plt
import colorsys
from PIL import Image
import os
import glob
from pylab import *

path = r'C:\Users\ckdillon\Desktop\450\spectrogram\spectroInHere\hourlySpect'
os.environ["PROJ_LIB"] = r"C:\Users\ckdillon\Anaconda3\Library\share";

# %%
img_file = Image.open("KEY.jpg")
answerKey = img_file.load()
[xs, ys] = img_file.size


redMeterred = 0
greenMeterred = 0
blueMeterred = 0
redMeteryellow = 0
greenMeteryellow = 0
blueMeteryellow = 0
redMeterblue = 0
greenMeterblue = 0
blueMeterblue = 0
meterCounter = 0


for x in range(0, xs):
    for y in range(0, ys):
   
    # (4)  Get the RGB color of the pixel
        [r, g, b] = answerKey[x, y]
        
        if y < (((ys)*(1/9))):
            redMeterred = redMeterred + r
            greenMeterred = greenMeterred + g
            blueMeterred = blueMeterred + b
            meterCounter = meterCounter + 1
        elif (y > ((ys*4/9))) and (y < ((ys*5/9))):
            redMeteryellow = redMeteryellow + r
            greenMeteryellow = greenMeteryellow + g
            blueMeteryellow = blueMeteryellow + b
        elif y > (((ys)*(8/9))):
            redMeterblue = redMeterblue + r
            greenMeterblue = greenMeterblue + g
            blueMeterblue = blueMeterblue + b
     
        # (5)  Normalize pixel color values

        r /= 255.0
        g /= 255.0
        b /= 255.0
        # (6)  Convert RGB color to HSV
            
redMetP = (redMeterred/meterCounter)/ (redMeterred/meterCounter+greenMeterred/meterCounter+blueMeterred/meterCounter)
greenMetP = (redMeteryellow/meterCounter)/ (redMeteryellow/meterCounter+greenMeteryellow/meterCounter+blueMeteryellow/meterCounter)
blueMetP = (redMeterblue/meterCounter)/ (redMeterblue/meterCounter+greenMeterblue/meterCounter+blueMeterblue/meterCounter)
print (redMeterred/meterCounter, greenMeterred/meterCounter, blueMeterred/meterCounter)
print (redMeteryellow/meterCounter, greenMeteryellow/meterCounter, blueMeteryellow/meterCounter)
print (redMeterblue/meterCounter, greenMeterblue/meterCounter, blueMeterblue/meterCounter)
print (redMetP)
print (greenMetP)
print (blueMetP)
# Out:
# 173.2368815592204 60.85157421289355 89.41929035482259
# 220.91254372813594 220.45727136431785 168.45327336331835
# 77.80659670164917 107.83308345827086 165.247876061969
# 0.5354953123479352
# 0.3622567723494087
# 0.221742251390776

# %%
red10 = 0
green10 = 0
blue10 = 0
redP10Array = []
greenP10Array = []
blueP10Array = []


for infile in glob.glob( os.path.join(path, '*.jpg') ):
    dayred10 = 0
    daygreen10 = 0
    dayblue10 = 0
    
    avgCounter = 0
    # (1) Import the file to be analyzed!
    img_file = Image.open(infile)
    img = img_file.load()
    # (2) Get image width & height in pixels
    [xs, ys] = img_file.size
    max_intensity = 100
    hues = {}
    count = 0
    # (3) Examine each pixel in the image file
    for x in range(0, xs):
        for y in range(0, ys):

        # (4)  Get the RGB color of the pixel
            [r, g, b] = img[x, y]
            if y < (((ys)*(5/5))):
                dayred10 = dayred10 + r
                daygreen10 = daygreen10 + g
                dayblue10 = dayblue10 + b
                avgCounter = avgCounter + 1

            # (5)  Normalize pixel color values

            r /= 255.0
            g /= 255.0
            b /= 255.0

    red10 = red10 + dayred10
    green10 = green10 + daygreen10
    blue10 = blue10 + dayblue10
   

    avgRed10 = red10 / avgCounter
    avgGreen10 = green10 / avgCounter
    avgBlue10 = blue10 / avgCounter
   

    redP10Array = np.append(redP10Array,(avgRed10 / (avgRed10 + avgGreen10 + avgBlue10)))
    greenP10Array = np.append(greenP10Array, (avgGreen10 / (avgRed10 + avgGreen10 + avgBlue10)))
    blueP10Array = np.append(blueP10Array,(avgBlue10 / (avgRed10 + avgGreen10 + avgBlue10)))


#print (redP10Array)
#print('break')
#print(greenP10Array)
#print('break')
#print(blueP10Array)


# (8)   Decompose the hues object into a set of one dimensional arrays we can use with matplotlib

# %%
red100 = 0
green100 = 0
blue100 = 0


redP100Array = []
greenP100Array = []
blueP100Array = []


for infile in glob.glob( os.path.join(path, '*.jpg') ):
    dayred100 = 0
    daygreen100 = 0
    dayblue100 = 0
   
    avgCounter = 0
    # (1) Import the file to be analyzed!
    img_file = Image.open(infile)
    img = img_file.load()
    # (2) Get image width & height in pixels
    [xs, ys] = img_file.size
    count = 0
    # (3) Examine each pixel in the image file
    for x in range(0, xs):
        for y in range(0, ys):

        # (4)  Get the RGB color of the pixel
            [r, g, b] = img[x, y]

            if y < (((ys)*(4/5))):
                dayred100 = dayred100 + r
                daygreen100 = daygreen100 + g
                dayblue100 = dayblue100 + b
                avgCounter = avgCounter + 1
           

            # (5)  Normalize pixel color values

            r /= 255.0
            g /= 255.0
            b /= 255.0
            # (6)  Convert RGB color to HSV
            

   
    red100 = red100 + dayred100
    green100 = green100 + daygreen100
    blue100 = blue100 + dayblue100

    avgRed100 = red100 / avgCounter
    avgGreen100 = green100 / avgCounter
    avgBlue100 = blue100 / avgCounter

    redP100Array = np.append(redP100Array,(avgRed100 / (avgRed100 + avgGreen100 + avgBlue100)))
    greenP100Array = np.append(greenP100Array, (avgGreen100 / (avgRed100 + avgGreen100 + avgBlue100)))
    blueP100Array = np.append(blueP100Array,(avgBlue100 / (avgRed100 + avgGreen100 + avgBlue100)))

    

#print (redP10Array)
#print('break')
#print(greenP10Array)
print('break')
#print(blueP10Array)


# (8)   Decompose the hues object into a set of one dimensional arrays we can use with matplotlib
# Out:
# [0.34442095 0.34339212 0.34354681 0.34609198 0.34553687 0.34522999
#  0.34566345 0.34603122 0.34634356 0.34643739 0.34688357 0.34703711
#  0.3468032  0.34670583 0.34668953 0.34703993 0.34743864 0.34776063
#  0.34776528 0.34763449 0.34739028 0.34706049 0.34667988 0.34679454
#  0.34643604 0.34599144 0.34617476 0.34653853 0.34633928 0.34624893
#  0.34621646 0.3461762  0.3461556  0.34609626 0.34630745 0.34623087
#  0.34620309 0.34619713 0.34620649 0.34615799 0.34608049 0.34584435
#  0.34582455 0.34556593 0.34516988 0.34542057 0.34509778 0.34491458
#  0.3447299  0.34460079 0.34444534 0.3444002  0.34452879 0.34478039
#  0.34504004 0.34528526 0.34542971 0.34566895 0.34598453 0.34629078
#  0.34668206 0.3470845  0.34750286 0.34789871 0.34827552 0.3486433
#  0.34897309 0.34912346 0.34951345 0.34975309 0.34993732 0.35007677
#  0.35023158 0.3503665  0.35060267 0.35079002 0.35101379 0.35131539
#  0.3514146  0.35170354 0.35200541 0.35220126 0.35238171 0.35257056
# ...

# %%
red1000 = 0
green1000 = 0
blue1000 = 0

redP1000Array = []
greenP1000Array = []
blueP1000Array = []

for infile in glob.glob( os.path.join(path, '*.jpg') ):
   
    dayred1000 = 0
    daygreen1000 = 0
    dayblue1000 = 0
   
    avgCounter = 0
    # (1) Import the file to be analyzed!
    img_file = Image.open(infile)
    img = img_file.load()
    # (2) Get image width & height in pixels
    [xs, ys] = img_file.size
    count = 0
    # (3) Examine each pixel in the image file
    for x in range(0, xs):
        for y in range(0, ys):

        # (4)  Get the RGB color of the pixel
            [r, g, b] = img[x, y]

            if y < (((ys)*(3/5))):
                dayred1000 = dayred1000 + r
                daygreen1000 = daygreen1000 + g
                dayblue1000 = dayblue1000 + b
                avgCounter = avgCounter + 1


            # (5)  Normalize pixel color values

            r /= 255.0
            g /= 255.0
            b /= 255.0
            # (6)  Convert RGB color to HSV
           
   
    red1000 = red1000 + dayred1000
    green1000 = green1000 + daygreen1000
    blue1000 = blue1000 + dayblue1000
     
    avgRed1000 = red1000 / avgCounter
    avgGreen1000 = green1000 / avgCounter
    avgBlue1000 = blue1000 / avgCounter

    redP1000Array = np.append(redP1000Array,(avgRed1000 / (avgRed1000 + avgGreen1000 + avgBlue1000)))
    greenP1000Array = np.append(greenP1000Array, (avgGreen1000 / (avgRed1000 + avgGreen1000 + avgBlue1000)))
    blueP1000Array = np.append(blueP1000Array,(avgBlue1000 / (avgRed1000 + avgGreen1000 + avgBlue1000)))


#print (redP10Array)
#print('break')
#print(greenP10Array)
print('break')
#print(blueP10Array)


# (8)   Decompose the hues object into a set of one dimensional arrays we can use with matplotlib
# Out:
# break

# %%
red10000 = 0
green10000 = 0
blue10000 = 0

redP10000Array = []
greenP10000Array = []
blueP10000Array = []


for infile in glob.glob( os.path.join(path, '*.jpg') ):
  
    dayred10000 = 0
    daygreen10000 = 0
    dayblue10000 = 0

    avgCounter = 0
    # (1) Import the file to be analyzed!
    img_file = Image.open(infile)
    img = img_file.load()
    # (2) Get image width & height in pixels
    [xs, ys] = img_file.size

    count = 0
    # (3) Examine each pixel in the image file
    for x in range(0, xs):
        for y in range(0, ys):

        # (4)  Get the RGB color of the pixel
            [r, g, b] = img[x, y]
                
            if y < (((ys)*(2/5))): 
                dayred10000 = dayred10000 + r
                daygreen10000 = daygreen10000 + g
                dayblue10000 = dayblue10000 + b
                avgCounter = avgCounter + 1
           
            # (5)  Normalize pixel color values

            r /= 255.0
            g /= 255.0
            b /= 255.0



    red10000 = red10000 + dayred10000
    green10000 = green10000 + daygreen10000
    blue10000 = blue10000 + dayblue10000
   
    avgRed10000 = red10000 / avgCounter
    avgGreen10000 = green10000 / avgCounter
    avgBlue10000 = blue10000 / avgCounter

    redP10000Array = np.append(redP10000Array,(avgRed10000 / (avgRed10000 + avgGreen10000 + avgBlue10000)))
    greenP10000Array = np.append(greenP10000Array, (avgGreen10000 / (avgRed10000 + avgGreen10000 + avgBlue10000)))
    blueP10000Array = np.append(blueP10000Array,(avgBlue10000 / (avgRed10000 + avgGreen10000 + avgBlue10000)))


#print (redP10Array)
#print('break')
#print(greenP10Array)
print('break')
#print(blueP10Array)


# (8)   Decompose the hues object into a set of one dimensional arrays we can use with matplotlib
# Out:
# break

# %%
red100000 = 0
green100000 = 0
blue100000 = 0

redP100000Array = []
greenP100000Array = []
blueP100000Array = []

for infile in glob.glob( os.path.join(path, '*.jpg') ):
    dayred100000 = 0
    daygreen100000 = 0
    dayblue100000 = 0
    avgCounter = 0
    # (1) Import the file to be analyzed!
    img_file = Image.open(infile)
    img = img_file.load()
    # (2) Get image width & height in pixels
    [xs, ys] = img_file.size
    count = 0
    # (3) Examine each pixel in the image file
    for x in range(0, xs):
        for y in range(0, ys):

        # (4)  Get the RGB color of the pixel
            [r, g, b] = img[x, y]

            if y < (((ys)*(1/5))):
                dayred100000 = dayred100000 + r
                daygreen100000 = daygreen100000 + g
                dayblue100000 = dayblue100000 + b
                avgCounter = avgCounter + 1

            # (5)  Normalize pixel color values

            r /= 255.0
            g /= 255.0
            b /= 255.0
            # (6)  Convert RGB color to HSV
           
   
    red100000 = red100000 + dayred100000
    green100000 = green100000 + daygreen100000
    blue100000 = blue100000 + dayblue100000

    avgRed100000 = red100000 / avgCounter
    avgGreen100000 = green100000 / avgCounter
    avgBlue100000 = blue100000 / avgCounter

    redP100000Array = np.append(redP100000Array,(avgRed100000 / (avgRed100000 + avgGreen100000 + avgBlue100000)))
    greenP100000Array = np.append(greenP100000Array, (avgGreen100000 / (avgRed100000 + avgGreen100000 + avgBlue100000)))
    blueP100000Array = np.append(blueP100000Array,(avgBlue100000 / (avgRed100000 + avgGreen100000 + avgBlue100000)))

#print (redP10Array)
#print('break')
#print(greenP10Array)
print('break')
#print(blueP10Array)


# (8)   Decompose the hues object into a set of one dimensional arrays we can use with matplotlib
# Out:
# break

# %%
yTran = [x for x in redP10Array]

# %%
moonIn = [5.59,11.2,18.85,28.81,38.86,50.28,61.82,72.8,82.54,90.47,96.13,99.26,99.77,97.77,93.51,87.35,79.71,71.04,61.75,52.22,42.78,33.7,25.22,17.57,10.99]
moonP  = [x / 100 for x in moonIn]


moonlength = len(moonP)
m = np.linspace(0,25,moonlength)
y =  redP10Array    
y1 = greenP10Array
y2 = blueP10Array
print(len(y))

x = np.linspace(0, 25, len(y))
plt.rcParams["figure.figsize"] = [7,5]
plt.rcParams['lines.linewidth'] = 1
plt.plot(x, y, 'r_', label='% red at 10Hz')
plt.plot(x, y1, 'y_', label='% green at 10Hz')
plt.plot(x, y2, 'b_', label='% blue at 10Hz')
plt.plot(m,moonP,'-',label='% moon visible')
plt.plot([0,25],[redMetP,redMetP],'m',label='% Red in full Red')
#plt.plot([0,25],[greenMetP,greenMetP],'*',label='% Red in full yellow')
#plt.plot([0,25],[blueMetP,blueMetP],'*',label='% Red in full blue')
plt.title('10Hz')
plt.ylabel('Volume(db) by reltive % of color in image pixels')
plt.xlabel('days')
plt.legend(loc='best')

plt.show()

y3 = redP100Array
y4 = greenP100Array
y5 = blueP100Array
plt.rcParams["figure.figsize"] = [7,5]
plt.plot(x, y3, 'r_', label='% red at 100Hz')
plt.plot(x, y4, 'y_', label='% green at 100Hz')
plt.plot(x, y5, 'b_', label='% blue at 100Hz')
plt.plot(m,moonP,'-',label='% moon visible')
plt.plot([0,25],[redMetP,redMetP],'m',label='% Red in full Red')
#plt.plot([0,30],[greenMetP,greenMetP],label='% Red in full yellow')
#plt.plot([0,30],[blueMetP,blueMetP],label='% Red in full blue')
plt.title('100Hz')
plt.ylabel('Volume(db) by reltive % of color in image pixels')
plt.xlabel('days')
plt.legend(loc='best')
plt.show()

y6 = redP1000Array
y7 = greenP1000Array
y8 = blueP1000Array
plt.rcParams["figure.figsize"] = [7,5]
plt.plot(x, y6, 'r_', label='% red at 1000Hz')
plt.plot(x, y7, 'y_', label='% green at 1000Hz')
plt.plot(x, y8, 'b_', label='% blue at 1000Hz')
plt.plot(m,moonP,'-',label='% moon visible')
plt.plot([0,25],[redMetP,redMetP],'m',label='% Red in full Red')
#plt.plot([0,30],[greenMetP,greenMetP],label='% Red in full yellow')
#plt.plot([0,30],[blueMetP,blueMetP],label='% Red in full blue')
plt.title('1000Hz')
plt.ylabel('Volume(db) by reltive % of color in image pixels')
plt.xlabel('days')
plt.legend(loc='best')
plt.show()

y9 = redP10000Array
y10 = greenP10000Array
y11 = blueP10000Array
plt.rcParams["figure.figsize"] = [7,5]
plt.plot(x, y9, 'r_', label='% red at 10000Hz')
plt.plot(x, y10, 'y_', label='% green at 10000Hz')
plt.plot(x, y11, 'b_', label='% blue at 10000Hz')
plt.plot(m,moonP,'-',label='% moon visible')
plt.plot([0,25],[redMetP,redMetP],'m',label='% Red in full Red')
#plt.plot([0,30],[greenMetP,greenMetP],label='% Red in full yellow')
#plt.plot([0,30],[blueMetP,blueMetP],label='% Red in full blue')
plt.title('10000Hz')
plt.ylabel('Volume(db) by reltive % of color in image pixels')
plt.xlabel('days')
plt.legend(loc='best')
plt.show()

y12 = redP100000Array
y13 = greenP100000Array
y14 = blueP100000Array
plt.rcParams["figure.figsize"] = [7,5]
plt.plot(x, y12, 'r_', label='% red at 100000Hz')
plt.plot(x, y13, 'y_', label='% green at 100000Hz')
plt.plot(x, y14, 'b_',label='% blue at 100000Hz')
plt.plot(m,moonP,'-',label='% moon visible')
plt.plot([0,25],[redMetP,redMetP],'m',label='% Red in full Red')
#plt.plot([0,30],[greenMetP,greenMetP],label='% Red in full yellow')
#plt.plot([0,30],[blueMetP,blueMetP],label='% Red in full blue')
plt.title('100000Hz')
plt.ylabel('Volume(db) by reltive % of color in image pixels')
plt.xlabel('days')
plt.legend(loc='best')
plt.show()
# Out:
# 547
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-161d47b73832> in <module>
#      28 plt.show()
#      29
# ---> 30 y3 = redP100Array
#      31 y4 = greenP100Array
#      32 y5 = blueP100Array
#
# NameError: name 'redP100Array' is not defined

# %%
red100 = 0
green100 = 0
blue100 = 0
red1000 = 0
green1000 = 0
blue1000 = 0
red10000 = 0
green10000 = 0
blue10000 = 0
red100000 = 0
green100000 = 0
blue100000 = 0


redP100Array = []
greenP100Array = []
blueP100Array = []
redP1000Array = []
greenP1000Array = []
blueP1000Array = []
redP10000Array = []
greenP10000Array = []
blueP10000Array = []
redP100000Array = []
greenP100000Array = []
blueP100000Array = []

for infile in glob.glob( os.path.join(path, '*.jpg') ):
    dayred10 = 0
    daygreen10 = 0
    dayblue10 = 0
    dayred100 = 0
    daygreen100 = 0
    dayblue100 = 0
    dayred1000 = 0
    daygreen1000 = 0
    dayblue1000 = 0
    dayred10000 = 0
    daygreen10000 = 0
    dayblue10000 = 0
    dayred100000 = 0
    daygreen100000 = 0
    dayblue100000 = 0
    avgCounter = 0
    # (1) Import the file to be analyzed!
    img_file = Image.open(infile)
    img = img_file.load()
    # (2) Get image width & height in pixels
    [xs, ys] = img_file.size
    max_intensity = 100
    hues = {}
    count = 0
    # (3) Examine each pixel in the image file
    for x in range(0, xs):
        for y in range(0, ys):

        # (4)  Get the RGB color of the pixel
            [r, g, b] = img[x, y]

            if y < (((ys)*(1/5))):
                dayred100000 = dayred100000 + r
                daygreen100000 = daygreen100000 + g
                dayblue100000 = dayblue100000 + b
                avgCounter = avgCounter + 1
            elif y < (((ys)*(2/5))): 
                dayred10000 = dayred10000 + r
                daygreen10000 = daygreen10000 + g
                dayblue10000 = dayblue10000 + b
            elif y < (((ys)*(3/5))):
                dayred1000 = dayred1000 + r
                daygreen1000 = daygreen1000 + g
                dayblue1000 = dayblue1000 + b
            elif y < (((ys)*(4/5))):
                dayred100 = dayred100 + r
                daygreen100 = daygreen100 + g
                dayblue100 = dayblue100 + b
            elif y < (((ys)*(5/5))):
                dayred10 = dayred10 + r
                daygreen10 = daygreen10 + g
                dayblue10 = dayblue10 + b

            # (5)  Normalize pixel color values

            r /= 255.0
            g /= 255.0
            b /= 255.0
            # (6)  Convert RGB color to HSV
            [h, s, v] = colorsys.rgb_to_hsv(r, g, b)

            # (7)  Marginalize s; count how many pixels have matching (h, v)
            if h not in hues:
              hues[h] = {}
            if v not in hues[h]:
              hues[h][v] = 1
            else:
              if hues[h][v] < max_intensity:
                hues[h][v] += 1 


    red10 = red10 + dayred10
    green10 = green10 + daygreen10
    blue10 = blue10 + dayblue10
    red100 = red100 + dayred100
    green100 = green100 + daygreen100
    blue100 = blue100 + dayblue100
    red1000 = red1000 + dayred1000
    green1000 = green1000 + daygreen1000
    blue1000 = blue1000 + dayblue1000
    red10000 = red10000 + dayred10000
    green10000 = green10000 + daygreen10000
    blue10000 = blue10000 + dayblue10000
    red100000 = red100000 + dayred100000
    green100000 = green100000 + daygreen100000
    blue100000 = blue100000 + dayblue100000

    avgRed10 = red10 / avgCounter
    avgGreen10 = green10 / avgCounter
    avgBlue10 = blue10 / avgCounter
    avgRed100 = red100 / avgCounter
    avgGreen100 = green100 / avgCounter
    avgBlue100 = blue100 / avgCounter
    avgRed1000 = red1000 / avgCounter
    avgGreen1000 = green1000 / avgCounter
    avgBlue1000 = blue1000 / avgCounter
    avgRed10000 = red10000 / avgCounter
    avgGreen10000 = green10000 / avgCounter
    avgBlue10000 = blue10000 / avgCounter
    avgRed100000 = red100000 / avgCounter
    avgGreen100000 = green100000 / avgCounter
    avgBlue100000 = blue100000 / avgCounter

    redP10Array = np.append(redP10Array,(avgRed10 / (avgRed10 + avgGreen10 + avgBlue10)))
    greenP10Array = np.append(greenP10Array, (avgGreen10 / (avgRed10 + avgGreen10 + avgBlue10)))
    blueP10Array = np.append(blueP10Array,(avgBlue10 / (avgRed10 + avgGreen10 + avgBlue10)))

    redP100Array = np.append(redP100Array,(avgRed100 / (avgRed100 + avgGreen100 + avgBlue100)))
    greenP100Array = np.append(greenP100Array, (avgGreen100 / (avgRed100 + avgGreen100 + avgBlue100)))
    blueP100Array = np.append(blueP100Array,(avgBlue100 / (avgRed100 + avgGreen100 + avgBlue100)))

    redP1000Array = np.append(redP1000Array,(avgRed1000 / (avgRed1000 + avgGreen1000 + avgBlue1000)))
    greenP1000Array = np.append(greenP1000Array, (avgGreen1000 / (avgRed1000 + avgGreen1000 + avgBlue1000)))
    blueP1000Array = np.append(blueP1000Array,(avgBlue1000 / (avgRed1000 + avgGreen1000 + avgBlue1000)))

    redP10000Array = np.append(redP10000Array,(avgRed10000 / (avgRed10000 + avgGreen10000 + avgBlue10000)))
    greenP10000Array = np.append(greenP10000Array, (avgGreen10000 / (avgRed10000 + avgGreen10000 + avgBlue10000)))
    blueP10000Array = np.append(blueP10000Array,(avgBlue10000 / (avgRed10000 + avgGreen10000 + avgBlue10000)))

    redP100000Array = np.append(redP100000Array,(avgRed100000 / (avgRed100000 + avgGreen100000 + avgBlue100000)))
    greenP100000Array = np.append(greenP100000Array, (avgGreen100000 / (avgRed100000 + avgGreen100000 + avgBlue100000)))
    blueP100000Array = np.append(blueP100000Array,(avgBlue100000 / (avgRed100000 + avgGreen100000 + avgBlue100000)))

#print (redP10Array)
#print('break')
#print(greenP10Array)
print('break')
#print(blueP10Array)


# (8)   Decompose the hues object into a set of one dimensional arrays we can use with matplotlib
